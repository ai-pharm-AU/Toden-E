# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd

# %%
from itertools import combinations
from scipy.stats import hypergeom
import math

class CoCo:
    """Class to calculate the CoCo Score for a given gene-set in a network."""
    def __init__(self, total_nodes, total_interactions, total_triangles, local_nodes, local_interactions, local_triangles):
        self.Nint = total_nodes * (total_nodes - 1) / 2
        self.Kint = total_interactions
        self.nint = local_nodes * (local_nodes - 1) / 2
        self.kint = local_interactions
        self.Ntri = total_nodes * (total_nodes - 1) * (total_interactions - 2) / 6
        self.Ktri = total_triangles
        self.ntri = local_nodes * (local_nodes - 1) * (local_nodes - 2) / 6
        self.ktri = local_triangles

    def _compute_score(self, k, n, K, N):
        if k == 0 or n == 0:
            return 0
        sign = (k / n) - (K / N)
        p = hypergeom.pmf(k, N, K, n)
        return 0 if p == 0 else abs(math.log10(p)) * (-1 if sign < 0 else 1)

    @property
    def CoI(self):
        return self._compute_score(self.kint, self.nint, self.Kint, self.Nint)

    @property
    def CoT(self):
        return self._compute_score(self.ktri, self.ntri, self.Ktri, self.Ntri)

    @property
    def coco(self):
        return self.CoI + self.CoT




class WeightedGraph:
    def __init__(self):
        self.graph = {}

    def node_exists(self, node):
        """Check if a node exists in the graph."""
        return node in self.graph

    def edge_exists(self, node1, node2):
        """Check if an edge exists between node1 and node2."""
        return self.node_exists(node1) and node2 in self.graph[node1]

    def add_node(self, node):
        """Add a node to the graph."""
        if not self.node_exists(node):
            self.graph[node] = {}

    def add_edge(self, node1, node2, weight):
        """Add an edge between node1 and node2 with the given weight."""
        if not self.edge_exists(node1, node2):
            # If the nodes don't exist, add them to the graph
            self.add_node(node1)
            self.add_node(node2)

            # Add node2 as a neighbor of node1 and vice versa
            self.graph[node1][node2] = float(weight)
            # self.graph[node2][node1] = weight  # Assuming it's an undirected graph

    @property
    def get_triangles_count(self):
        triangles = 0

        for node in self.graph:
            neighbors = list(self.graph[node].keys())
            for i in range(len(neighbors)):
                for j in range(i+1, len(neighbors)):
                    if self.edge_exists(neighbors[i], neighbors[j]):
                        triangles += 1

        # Each triangle is counted 3 times (once for each node), so divide by 3
        return triangles // 3

    @property
    def get_edges_count(self, threshold=0.45):
        total_edges = sum(1 for neighbors in self.graph.values() for weight in neighbors.values() if weight > threshold)
        return total_edges // 2



    def __str__(self):
        return str(self.graph)

def count_edges_in_subgraph(graph, nodes):
    edge_count = 0

    # Check each pair of nodes
    for i in range(len(nodes)):
        for j in range(i+1, len(nodes)):
            if nodes[j] in graph[nodes[i]]:
                edge_count += 1

    return edge_count

def count_triangles_in_subgraph(graph, nodes):
    triangle_count = 0

    # Check every combination of three nodes
    for i in range(len(nodes)):
        for j in range(i+1, len(nodes)):
            for k in range(j+1, len(nodes)):
                node1, node2, node3 = nodes[i], nodes[j], nodes[k]
                if (node2 in graph[node1] and node3 in graph[node1] and
                    node3 in graph[node2]):
                    triangle_count += 1

    return triangle_count

def find_max_coco_subgraph(graph):  # Added threshold parameter with default value 0
    nodes = list(graph.graph.keys())
    total_nodes = len(nodes)
    total_interactions = graph.get_edges_count if hasattr(graph, 'get_edges_count') else 0
    # For simplicity, let's assume the graph has a method to compute total triangles
    total_triangles = graph.get_triangles_count if hasattr(graph, 'get_triangles_count') else 0

    max_score = -float('inf')
    best_subgraph = None

    # For simplicity, let's check all subgraphs of size 3
    for subgraph_nodes in combinations(nodes, 5):
        local_nodes = len(subgraph_nodes)

        # Count edges in the subgraph using the provided function
        local_interactions = count_edges_in_subgraph(graph.graph, subgraph_nodes)

        # Count triangles in the subgraph using the provided function
        local_triangles = count_triangles_in_subgraph(graph.graph, subgraph_nodes)

        coco = CoCo(total_nodes, total_interactions, total_triangles, local_nodes, local_interactions, local_triangles)
        if coco.coco > max_score:
            max_score = coco.coco
            best_subgraph = subgraph_nodes
            print(f'best sub: {best_subgraph}, max coco: {max_score}')

    return best_subgraph, max_score

# %%
############################################
### PAGER functions for PAGER server API ###
############################################
import requests
import numpy as np
import pandas as pd
class PAGER():
    def __init__(self):
        self.params = {}

    ######
    # run_pager is a function connected to PAGER api to perform hypergeometric test and retrieve enriched PAGs associated to a list of genes
    # The input parameters are:
    # 1.genes: a list of gene symbols.
    # 2.source: a list of sources refered to 'http://discovery.informatics.uab.edu/PAGER/index.php/pages/help'
    # 3.Type: a list of PAG types consisting of 'P', 'A' or 'G'
    # 4.minSize: the allowed minimum size of PAG genes
    # 5.maxSize: the allowed maximum size of PAG genes
    # 6.similarity: the similarity score cutoff [0,1]
    # 7.overlap: the allowed minimum overlap genes
    # 8.nCoCo: the minimum nCoCo score
    # 9.pValue: p-value cutoff
    # 10.FDR: false discovery rate
    ######
    def run_pager(self, genes,**kwargs):
        source = kwargs['source'] if 'source' in kwargs.keys() else ['KEGG_2021_HUMAN', 'WikiPathway_2021', 'BioCarta', 'Reactome_2021', 'Spike']
        Type = kwargs['Type'] if 'Type' in kwargs.keys() else 'All'
        minSize = kwargs['minSize'] if 'minSize' in kwargs.keys() else 1
        maxSize = kwargs['maxSize'] if 'maxSize' in kwargs.keys() else 2000
        sim = kwargs['similarity'] if 'similarity' in kwargs.keys() else 0
        overlap = kwargs['overlap'] if 'overlap' in kwargs.keys() else '1'
        organism = kwargs['organism'] if 'organism' in kwargs.keys() else 'All'
        nCoCo = kwargs['nCoCo'] if 'nCoCo' in kwargs.keys() else '0'
        pvalue = kwargs['pvalue'] if 'pvalue' in kwargs.keys() else 0.05
        FDR = kwargs['FDR'] if 'FDR' in kwargs.keys() else 0.05
        # Set up the call parameters as a dict.
        params = {}
        # Work around PAGER API form encode issue.
        params['genes'] = '%20'.join(genes)
        params['source'] = '%20'.join(source)
        params['type'] = Type
        params['ge'] = minSize
        params['le'] = maxSize
        params['sim'] = str(sim)
        params['olap'] = str(overlap)
        params['organism'] = organism
        params['cohesion'] = str(nCoCo)
        params['pvalue'] = pvalue
        params['FDR'] = FDR
        response = requests.post('http://discovery.informatics.uab.edu/PAGER/index.php/geneset/pagerapi', data=params)
        #print(response.request.body)
        return pd.DataFrame(response.json())

    # pathMember is a function connected to PAGER api to retrieve the membership of PAGs using a list of PAG IDs
    def pathMember(self, PAG_IDs):
        # Set up the call parameters as a dict.
        params = {}
        params['pag'] = ','.join(PAG_IDs)
        # Work around PAGER API form encode issue.
        response = requests.post('http://discovery.informatics.uab.edu/PAGER/index.php/geneset/get_members_by_ids/', data=params)
        #print(response.request.body)
        return pd.DataFrame(response.json()['data'])

    # pathInt is a function connected to PAGER api to retrieve the m-type relationships of PAGs using a list of PAG IDs
    def pathInt(self, PAG_IDs):
        # Set up the call parameters as a dict.
        params = {}
        params['pag'] = ','.join(PAG_IDs)
        # Work around PAGER API form encode issue.
        response = requests.post('http://discovery.informatics.uab.edu/PAGER/index.php/pag_pag/inter_network_int_api/', data=params)
        #print(response.request.body)
        return pd.DataFrame(response.json()['data'])

    # pathReg is a function connected to PAGER api to retrieve the r-type relationships of PAGs using a list of PAG IDs
    def pathReg(self, PAG_IDs):
        # Set up the call parameters as a dict.
        params = {}
        params['pag'] = ','.join(PAG_IDs)
        # Work around PAGER API form encode issue.
        response = requests.post('http://discovery.informatics.uab.edu/PAGER/index.php/pag_pag/inter_network_reg_api/', data=params)
        #print(response.request.body)
        return pd.DataFrame(response.json()['data'])

    # pagRankedGene is a function connected to PAGER api to retrieve RP-ranked genes with RP-score of the given PAG_IDs
    def pagRankedGene(self, PAGid):
        response = requests.get('http://discovery.informatics.uab.edu/PAGER/index.php/genesinPAG/viewgenes/'+PAGid)
        return pd.DataFrame(response.json()['gene'])

    # pagGeneInt is a function connected to PAGER api to retrieve gene interaction network
    def pagGeneInt(self, PAGid):
        response = requests.get('http://discovery.informatics.uab.edu/PAGER/index.php/pag_mol_mol_map/interactions/'+PAGid)
        return pd.DataFrame(response.json()['data'])

    # pagGeneReg is a function connected to PAGER api to retrieve gene regulatory network
    def pagGeneReg(self, PAGid):
        response = requests.get('http://discovery.informatics.uab.edu/PAGER/index.php/pag_mol_mol_map/regulations/'+PAGid)
        return pd.DataFrame(response.json()['data'])

    # path_NGSEA is a function connected to PAGER api to generate the network-based GSEA result
    import requests
    def path_NGSEA(SELF, genes, PAGmember):
        geneExpStr = ''
        for rowIdx in range(0,genes.shape[0]):
            geneExpStr = geneExpStr + genes.iloc[rowIdx,0]+'\\t\\t'+genes.iloc[rowIdx,1] + "\\t\\t\\t"
        PAGsetsStr = ''
        for rowIdx in range(0,PAGmember.shape[0]):
            PAGsetsStr = PAGsetsStr + PAGmember.iloc[rowIdx,0]+'\\t\\t'+PAGmember.iloc[rowIdx,1] + "\\t\\t\\t"
        params = {}
        params['geneExpStr'] = geneExpStr
        params['PAGsetsStr'] = PAGsetsStr
        response = requests.post('http://discovery.informatics.uab.edu/PAGER/index.php/geneset/ngseaapi/', data=params)
        #print(response.request.body)
        return pd.DataFrame(response.json()['data'])

# %%
PAGER = PAGER()

# %%
######
# run_pager is a function connected to PAGER api to perform hypergeometric test and retrieve enriched PAGs associated to a list of genes
# The input parameters are:
# 1.genes: a list of gene symbols.
# 2.source: a list of sources refered to 'http://discovery.informatics.uab.edu/PAGER/index.php/pages/help'
# 3.Type: a list of PAG types consisting of 'P', 'A' or 'G'
# 4.minSize: the allowed minimum size of PAG genes
# 5.maxSize: the allowed maximum size of PAG genes
# 6.similarity: the similarity score cutoff [0,1]
# 7.overlap: the allowed minimum overlap genes
# 8.nCoCo: the minimum nCoCo score
# 9.pValue: p-value cutoff
# 10.FDR: false discovery rate
######
PAG_result = PAGER.run_pager(
    ['BRCA1','BRCA2'],
    source = ['KEGG_2021_HUMAN', 'WikiPathway_2021', 'BioCarta', 'Reactome_2021', 'Spike'],
    Type='All',
    minSize=1,
    maxSize=2000,
    similarity = 0.05,
    overlap = 1,
    nCoCo = 0,
    pValue = 0.05,
    FDR = 0.05
)
PAG_result
len(PAG_result)
# Out:
#         GS_ID                                               NAME  \
# 0   WAG002693                               Sandbox pathway test
# 1   WAG000644  role of brca1 brca2 and atr in cancer suscepti...
# 2   WAG004117            BCDX2 complex stabilizes RAD51 filament
# 3   WAG004154  D-loop formation mediated by PALB2, BRCA2 and ...
# 4   WAG004162  Defective D-loop formation mediated by PALB2, ...
# 5   WAG004163  Defective D-loop formation mediated by PALB2, ...
# 6   WAG004164  Defective D-loop formation mediated by PALB2, ...
# 7   WAG004118                CX3 complex binds D-loop structures
# 8   WAG004123  Resolution of D-loops cleaved by MUS81:EME1 or...
# 9   WAG004124  Resolution of Holliday junctions cleaved by GE...
# 10  WAG004136  Ligation of DNA and formation of Holliday stru...
# 11  WAG004121  BLM mediates dissolution of double Holliday ju...
# 12  WAG004147           D-loop dissociation and strand annealing
# 13  WAG003221                           Homologous recombination
# 14  WAG004122                     MUS81:EME1,EME2 cleaves D-loop
# 15  WAG004146  Cleavage of Holliday junctions by GEN1 or SLX1...
# 16  WAG004141             RAD51 binds BRCA2 at resected DNA DSBs
# 17  WAG001743  hsa03440 Homologous recombination - Homo sapie...
# 18  WAG004404  Formation of meiotic single-stranded DNA invas...
# 19  WAG004402                  Formation of meiotic heteroduplex
# 20  WAG004148                D-loop extension by DNA polymerases
# 21  WAG001745  hsa03460 Fanconi anemia pathway - Homo sapiens...
# 22  WAG002675  DNA IR-double strand breaks and cellular respo...
# 23  WAG002700        DNA IR-damage and cellular response via ATR
# 24  WAG002161                    Glioblastoma signaling pathways
# 25  WAG002265                              Meiotic recombination
# 26  WIG001822                   Repair of Interstrand Crosslinks
# 27  WAG003110                  DNA repair pathways, full network
# 28  WAG002505  HDR through Homologous Recombination (HRR) or ...
# 29  WAG001955      hsa05224 Breast cancer - Homo sapiens (human)
# 30  WAG002840                              Breast cancer pathway
# 31  WAG002125                   Integrated breast cancer pathway
# 32  WIG001825       DNA damage response and chromatin remodeling
# 33  WIG001819                                   Response to DSBs
# 34  WAG006529                         CHEK1 phosphorylates BRCA2
# 35  WAG014925               BRCA1 forms a heterodimer with BARD1
# 36  WAG014927    Some pathogenic BRCA1 mutants do not bind BARD1
# 37  WAG014928                Defective BARD1 does not bind BRCA1
# 38  WAG013979                UBXN1 binds BRCA1:BARD1 heterodimer
# 39  WAG014929          BAP1 disrupts the BRCA1:BARD1 heterodimer
# 40  WAG014931                 BAP1 binds BRCA1:BARD1 heterodimer
# 41  WAG008846         BRCA1 gene expression is inhibited by E2F6
# 42  WAG014174                PIAS1,4 SUMOylates BRCA1 with SUMO1
# 43  WAG014173              PIAS1,4 SUMOylates BRCA1 with SUMO2,3
# 44  WAG014930          BRCA1:BARD1 heterodimer autoubiquitinates
# 45  WAG000212                 brca1 dependent ub ligase activity
# 46  WAG004110                   BRCA1 binds phosphorylated RBBP8
# 47  WAG004152      Initial resection of double-strand break ends
# 48  WAG003241  SMC1/SMC3 role in DNA damage - Cornelia de Lan...
# 49  WAG002069                           Homologous recombination
# 50  WAG004340            Resolution of meiotic holliday junction
# 51  WAG004119  EXO1 or DNA2 in complex with BLM or WRN binds ...
# 52  WAG004120   Long-range resection of DNA DSBs by EXO1 or DNA2
# 53  WAG000628                              atm signaling pathway
# 54  WAG004138  Association of RPA complexes with ssDNA at res...
# 55  WIG001826                                      WNT signaling
# 56  WAG001933  hsa05200 Pathways in cancer - Homo sapiens (hu...
#
#               SOURCE GS_SIZE      ORGANISM  \
# 0   WikiPathway_2021       5  Homo sapiens
# 1           BioCarta      21  Homo sapiens
# 2      Reactome_2021      22  Homo sapiens
# 3      Reactome_2021      24  Homo sapiens
# 4      Reactome_2021      24  Homo sapiens
# 5      Reactome_2021      24  Homo sapiens
# 6      Reactome_2021      24  Homo sapiens
# 7      Reactome_2021      25  Homo sapiens
# 8      Reactome_2021      25  Homo sapiens
# 9      Reactome_2021      25  Homo sapiens
# 10     Reactome_2021      25  Homo sapiens
# 11     Reactome_2021      26  Homo sapiens
# 12     Reactome_2021      26  Homo sapiens
# 13  WikiPathway_2021      28  Homo sapiens
# 14     Reactome_2021      28  Homo sapiens
# 15     Reactome_2021      32  Homo sapiens
# 16     Reactome_2021      34  Homo sapiens
# 17   KEGG_2021_HUMAN      41  Homo sapiens
# 18     Reactome_2021      44  Homo sapiens
# 19     Reactome_2021      45  Homo sapiens
# 20     Reactome_2021      48  Homo sapiens
# 21   KEGG_2021_HUMAN      54  Homo sapiens
# 22  WikiPathway_2021      55  Homo sapiens
# 23  WikiPathway_2021      80  Homo sapiens
# 24  WikiPathway_2021      83  Homo sapiens
# 25  WikiPathway_2021      88  Homo sapiens
# 26             Spike     102  Homo sapiens
# 27  WikiPathway_2021     120  Homo sapiens
# 28  WikiPathway_2021     132  Homo sapiens
# 29   KEGG_2021_HUMAN     147  Homo sapiens
# 30  WikiPathway_2021     155  Homo sapiens
# 31  WikiPathway_2021     157  Homo sapiens
# 32             Spike     157  Homo sapiens
# 33             Spike     164  Homo sapiens
# 34     Reactome_2021       2  Homo sapiens
# 35     Reactome_2021       2  Homo sapiens
# 36     Reactome_2021       2  Homo sapiens
# 37     Reactome_2021       2  Homo sapiens
# 38     Reactome_2021       3  Homo sapiens
# 39     Reactome_2021       3  Homo sapiens
# 40     Reactome_2021       3  Homo sapiens
# 41     Reactome_2021       4  Homo sapiens
# 42     Reactome_2021       5  Homo sapiens
# 43     Reactome_2021       6  Homo sapiens
# 44     Reactome_2021       7  Homo sapiens
# 45          BioCarta       8  Homo sapiens
# 46     Reactome_2021       8  Homo sapiens
# 47     Reactome_2021       8  Homo sapiens
# 48  WikiPathway_2021      11  Homo sapiens
# 49  WikiPathway_2021      13  Homo sapiens
# 50     Reactome_2021      13  Homo sapiens
# 51     Reactome_2021      16  Homo sapiens
# 52     Reactome_2021      16  Homo sapiens
# 53          BioCarta      18  Homo sapiens
# 54     Reactome_2021      19  Homo sapiens
# 55             Spike     448  Homo sapiens
# 56   KEGG_2021_HUMAN     531  Homo sapiens
#
#                                           DESCRIPTION  \
# 0                                Sandbox pathway test
# 1   BRCA1 and BRCA2 were identified genetically as...
# 2             BCDX2 complex stabilizes RAD51 filament
# 3   D-loop formation mediated by PALB2, BRCA2 and ...
# 4   Defective D-loop formation mediated by PALB2, ...
# 5   Defective D-loop formation mediated by PALB2, ...
# 6   Defective D-loop formation mediated by PALB2, ...
# 7                 CX3 complex binds D-loop structures
# 8   Resolution of D-loops cleaved by MUS81:EME1 or...
# 9   Resolution of Holliday junctions cleaved by GE...
# 10  Ligation of DNA and formation of Holliday stru...
# 11  BLM mediates dissolution of double Holliday ju...
# 12           D-loop dissociation and strand annealing
# 13                           Homologous recombination
# 14                     MUS81:EME1,EME2 cleaves D-loop
# 15  Cleavage of Holliday junctions by GEN1 or SLX1...
# 16             RAD51 binds BRCA2 at resected DNA DSBs
# 17  Homologous recombination (HR) is essential for...
# 18  Formation of meiotic single-stranded DNA invas...
# 19                  Formation of meiotic heteroduplex
# 20                D-loop extension by DNA polymerases
# 21  The Fanconi anemia pathway is required for the...
# 22  DNA IR-double strand breaks and cellular respo...
# 23        DNA IR-damage and cellular response via ATR
# 24                    Glioblastoma signaling pathways
# 25                              Meiotic recombination
# 26  Multiple pathways of DNA repair participate in...
# 27                  DNA repair pathways, full network
# 28  HDR through Homologous Recombination (HRR) or ...
# 29  Breast cancer is the leading cause of cancer d...
# 30                              Breast cancer pathway
# 31                   Integrated breast cancer pathway
# 32  The packaging of eukaryotic chromosomal DNA in...
# 33  DNA double-strand breaks (DSBs) arise in cells...
# 34                         CHEK1 phosphorylates BRCA2
# 35               BRCA1 forms a heterodimer with BARD1
# 36    Some pathogenic BRCA1 mutants do not bind BARD1
# 37                Defective BARD1 does not bind BRCA1
# 38                UBXN1 binds BRCA1:BARD1 heterodimer
# 39          BAP1 disrupts the BRCA1:BARD1 heterodimer
# 40                 BAP1 binds BRCA1:BARD1 heterodimer
# 41         BRCA1 gene expression is inhibited by E2F6
# 42                PIAS1,4 SUMOylates BRCA1 with SUMO1
# 43              PIAS1,4 SUMOylates BRCA1 with SUMO2,3
# 44          BRCA1:BARD1 heterodimer autoubiquitinates
# 45  BRCA1 is a breast and ovarian cancer tumor sup...
# 46                   BRCA1 binds phosphorylated RBBP8
# 47      Initial resection of double-strand break ends
# 48  SMC1/SMC3 role in DNA damage - Cornelia de Lan...
# 49                           Homologous recombination
# 50            Resolution of meiotic holliday junction
# 51  EXO1 or DNA2 in complex with BLM or WRN binds ...
# 52   Long-range resection of DNA DSBs by EXO1 or DNA2
# 53  The ataxia telangiectasia-mutated gene (ATM) e...
# 54  Association of RPA complexes with ssDNA at res...
# 55  The Wnt pathway plays a critical role in the d...
# 56                                               None
#
#                                                  LINK TYPE MULTI_N OLAP  \
# 0   https://www.wikipathways.org/index.php/Pathway...    P    1333    2
# 1   https://cgap.nci.nih.gov/Pathways/BioCarta/h_a...    P     252    2
# 2   https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    2
# 3   https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    2
# 4   https://reactome.org/PathwayBrowser/#/R-HSA-97...    P   13163    2
# 5   https://reactome.org/PathwayBrowser/#/R-HSA-97...    P   13163    2
# 6   https://reactome.org/PathwayBrowser/#/R-HSA-97...    P   13163    2
# 7   https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    2
# 8   https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    2
# 9   https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    2
# 10  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    2
# 11  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    2
# 12  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    2
# 13  https://www.wikipathways.org/index.php/Pathway...    P    1333    2
# 14  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    2
# 15  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    2
# 16  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    2
# 17             https://www.genome.jp/pathway/hsa03440    P     345    2
# 18  https://reactome.org/PathwayBrowser/#/R-HSA-91...    P   13163    2
# 19  https://reactome.org/PathwayBrowser/#/R-HSA-91...    P   13163    2
# 20  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    2
# 21             https://www.genome.jp/pathway/hsa03460    P     345    2
# 22  https://www.wikipathways.org/index.php/Pathway...    P    1333    2
# 23  https://www.wikipathways.org/index.php/Pathway...    P    1333    2
# 24  https://www.wikipathways.org/index.php/Pathway...    P    1333    2
# 25  https://www.wikipathways.org/index.php/Pathway...    P    1333    2
# 26  http://www.cs.tau.ac.il/~spike/maps/spike00007...    P      28    2
# 27  https://www.wikipathways.org/index.php/Pathway...    P    1333    2
# 28  https://www.wikipathways.org/index.php/Pathway...    P    1333    2
# 29             https://www.genome.jp/pathway/hsa05224    P     345    2
# 30  https://www.wikipathways.org/index.php/Pathway...    P    1333    2
# 31  https://www.wikipathways.org/index.php/Pathway...    P    1333    2
# 32  http://www.cs.tau.ac.il/~spike/maps/spike00010...    P      28    2
# 33  http://www.cs.tau.ac.il/~spike/maps/spike00004...    P      28    2
# 34  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    1
# 35  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    1
# 36  https://reactome.org/PathwayBrowser/#/R-HSA-96...    P   13163    1
# 37  https://reactome.org/PathwayBrowser/#/R-HSA-96...    P   13163    1
# 38  https://reactome.org/PathwayBrowser/#/R-HSA-97...    P   13163    1
# 39  https://reactome.org/PathwayBrowser/#/R-HSA-97...    P   13163    1
# 40  https://reactome.org/PathwayBrowser/#/R-HSA-97...    P   13163    1
# 41  https://reactome.org/PathwayBrowser/#/R-HSA-90...    P   13163    1
# 42  https://reactome.org/PathwayBrowser/#/R-HSA-29...    P   13163    1
# 43  https://reactome.org/PathwayBrowser/#/R-HSA-29...    P   13163    1
# 44  https://reactome.org/PathwayBrowser/#/R-HSA-97...    P   13163    1
# 45  https://cgap.nci.nih.gov/Pathways/BioCarta/h_b...    P     252    1
# 46  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    1
# 47  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    1
# 48  https://www.wikipathways.org/index.php/Pathway...    P    1333    1
# 49  https://www.wikipathways.org/index.php/Pathway...    P    1333    1
# 50  https://reactome.org/PathwayBrowser/#/R-HSA-91...    P   13163    1
# 51  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    1
# 52  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    1
# 53  https://cgap.nci.nih.gov/Pathways/BioCarta/h_a...    P     252    1
# 54  https://reactome.org/PathwayBrowser/#/R-HSA-56...    P   13163    1
# 55  http://www.cs.tau.ac.il/~spike/maps/spike00027...    P      28    1
# 56             https://www.genome.jp/pathway/hsa05200    P     345    1
#
#         COCO_V2                           SIMILARITY_SCORE        pvalue  \
# 0    188.558608                                        .52  1.020749e-08
# 1   5956.815769  .2761904761904761904761904761904761904762  2.143572e-07
# 2   3370.353336  .2727272727272727272727272727272727272727  2.357930e-07
# 3   3436.072517  .2666666666666666666666666666666666666667  2.817267e-07
# 4   3436.072517  .2666666666666666666666666666666666666667  2.817267e-07
# 5   3436.072517  .2666666666666666666666666666666666666667  2.817267e-07
# 6   3436.072517  .2666666666666666666666666666666666666667  2.817267e-07
# 7   3687.288396                                       .264  3.062246e-07
# 8   3687.288396                                       .264  3.062246e-07
# 9   3687.288396                                       .264  3.062246e-07
# 10  3687.288396                                       .264  3.062246e-07
# 11  3402.224081  .2615384615384615384615384615384615384615  3.317434e-07
# 12  3402.224081  .2615384615384615384615384615384615384615  3.317434e-07
# 13  1940.666302  .2571428571428571428571428571428571428571  3.858430e-07
# 14  3336.772994  .2571428571428571428571428571428571428571  3.858430e-07
# 15  2709.154452                                        .25  5.062914e-07
# 16   6125.62014  .2470588235294117647058823529411764705882  5.726401e-07
# 17  2627.667251  .2390243902439024390243902439024390243902  8.370140e-07
# 18  115.3844923  .2363636363636363636363636363636363636364  9.656283e-07
# 19  150.0163697  .2355555555555555555555555555555555555556  1.010541e-06
# 20   5990.79972  .2333333333333333333333333333333333333333  1.151405e-06
# 21  2639.032014  .2296296296296296296296296296296296296296  1.460692e-06
# 22  2707.216113  .2290909090909090909090909090909090909091  1.515812e-06
# 23  4220.275213                                        .22  3.225566e-06
# 24  4976.097877   .219277108433734939759036144578313253012  3.473608e-06
# 25  344.1773602  .2181818181818181818181818181818181818182  3.907426e-06
# 26   5740.10268  .2156862745098039215686274509803921568627  5.257877e-06
# 27  6283.961347  .2133333333333333333333333333333333333333  7.288146e-06
# 28  2430.640086  .2121212121212121212121212121212121212121  8.825394e-06
# 29   3701.25203   .210884353741496598639455782312925170068  1.095366e-05
# 30  3126.072387  .2103225806451612903225806451612903225806  1.218264e-05
# 31  1553.397473  .2101910828025477707006369426751592356688  1.250009e-05
# 32  1569.958527  .2101910828025477707006369426751592356688  1.250009e-05
# 33  2707.633139  .2097560975609756097560975609756097560976  1.364333e-05
# 34  126.2105263  .3666666666666666666666666666666666666667  9.036281e-05
# 35  126.2105263  .3666666666666666666666666666666666666667  9.036281e-05
# 36  126.2105263  .3666666666666666666666666666666666666667  9.036281e-05
# 37  126.2105263  .3666666666666666666666666666666666666667  9.036281e-05
# 38  384.3965412                                         .3  1.355411e-04
# 39  134.1614907                                         .3  1.355411e-04
# 40  134.1614907                                         .3  1.355411e-04
# 41   756.782076                                        .26  1.807174e-04
# 42  1216.805852  .2333333333333333333333333333333333333333  2.258917e-04
# 43  1744.991383  .2142857142857142857142857142857142857143  2.710639e-04
# 44  1469.189466                                         .2  3.162341e-04
# 45  2952.437544  .1888888888888888888888888888888888888889  3.614022e-04
# 46  1317.698072  .1888888888888888888888888888888888888889  3.614022e-04
# 47  1317.698072  .1888888888888888888888888888888888888889  3.614022e-04
# 48  1793.045634  .1666666666666666666666666666666666666667  4.968944e-04
# 49  1401.916365  .1571428571428571428571428571428571428571  5.872123e-04
# 50  4341.774771  .1571428571428571428571428571428571428571  5.872123e-04
# 51  2154.832995  .1470588235294117647058823529411764705882  7.226738e-04
# 52  2154.832995  .1470588235294117647058823529411764705882  7.226738e-04
# 53  2452.469682  .1421052631578947368421052631578947368421  8.129713e-04
# 54  3183.379618                                        .14  8.581170e-04
# 55    1198.7612  .1017817371937639198218262806236080178174  2.003731e-02
# 56  2740.388822  .1015037593984962406015037593984962406015  2.370460e-02
#
#     Rank      pFDR
# 0      1  0.000001
# 1      2  0.000024
# 2      3  0.000026
# 3      4  0.000031
# 4      4  0.000030
# 5      4  0.000030
# 6      4  0.000030
# 7      8  0.000032
# 8      8  0.000032
# 9      8  0.000032
# 10     8  0.000031
# 11    12  0.000034
# 12    12  0.000033
# 13    14  0.000038
# 14    14  0.000038
# 15    16  0.000049
# 16    17  0.000055
# 17    18  0.000080
# 18    19  0.000091
# 19    20  0.000094
# 20    21  0.000106
# 21    22  0.000133
# 22    23  0.000136
# 23    24  0.000287
# 24    25  0.000306
# 25    26  0.000340
# 26    27  0.000452
# 27    28  0.000619
# 28    29  0.000741
# 29    30  0.000909
# 30    31  0.000999
# 31    32  0.001013
# 32    32  0.001000
# 33    34  0.001078
# 34    35  0.007048
# 35    35  0.006958
# 36    35  0.006868
# 37    35  0.006777
# 38    39  0.010030
# 39    39  0.009895
# 40    39  0.009759
# 41    42  0.012831
# 42    43  0.015812
# 43    44  0.018703
# 44    45  0.021504
# 45    46  0.024214
# 46    46  0.023853
# 47    46  0.023491
# 48    49  0.031801
# 49    50  0.036994
# 50    50  0.036407
# 51    52  0.044083
# 52    52  0.043360
# 53    54  0.047965
# 54    55  0.049771
# 55   111  0.040075
# 56   112  0.023705
# 57

# %%
# pagGeneInt is a function connected to PAGER api to retrieve gene interaction network
# example:

# pagGeneInts = PAGER.pagGeneInt(list(PAG_result.GS_ID)[0])
# %debug
all_pagGeneInts = pd.concat([PAGER.pagGeneInt(gs_id) for gs_id in list(PAG_result.GS_ID)], ignore_index=True)
all_pagGeneInts
pag_graph = WeightedGraph()
for node1, node2, weight in all_pagGeneInts.values.tolist():
  pag_graph.add_edge(node1, node2, weight)

pag_graph

BEST_SUB, MAX_COCO = find_max_coco_subgraph(pag_graph)

BEST_SUB
MAX_COCO
# Out:
#      SYM_A   SYM_B H_SCORE
# 0    BARD1   BRCA1       1
# 1    BARD1   FANCA    .921
# 2    BARD1   FANCC    .926
# 3    BARD1  FANCD2   .9732
# 4    BARD1   FANCE    .931
# ..     ...     ...     ...
# 360  RAD51   RAD9A    .888
# 361  RAD51    TP53   .9754
# 362  RAD9A    TP53    .871
# 363  RAD9A   TREX1   .6804
# 364   TP53   TREX1   .6764
#
# [365 rows x 3 columns]
# best sub: ('BARD1', 'BRCA1', 'ABL1', 'ATM', 'JUN'), max coco: 1.374965299512294
# best sub: ('BARD1', 'BRCA1', 'ABL1', 'JUN', 'RAD51'), max coco: 2.047478008546958
# best sub: ('BRCA1', 'FANCA', 'CHEK1', 'BRCA2', 'HUS1'), max coco: 2.8819895403124574
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#      10   pag_graph.add_edge(node1, node2, weight)
#      12 pag_graph
# ---> 14 BEST_SUB, MAX_COCO = find_max_coco_subgraph(pag_graph)
#      16 BEST_SUB
#      17 MAX_COCO
#
# Cell In[2], line 137, in find_max_coco_subgraph(graph)
#     134 local_triangles = count_triangles_in_subgraph(graph.graph, subgraph_nodes)
#     136 coco = CoCo(total_nodes, total_interactions, total_triangles, local_nodes, local_interactions, local_triangles)
# --> 137 if coco.coco > max_score:
#     138     max_score = coco.coco
#     139     best_subgraph = subgraph_nodes
#
# Cell In[2], line 34, in CoCo.coco(self)
#      32 @property
#      33 def coco(self):
# ---> 34     return self.CoI + self.CoT
#
# Cell In[2], line 26, in CoCo.CoI(self)
#      24 @property
#      25 def CoI(self):
# ---> 26     return self._compute_score(self.kint, self.nint, self.Kint, self.Nint)
#
# Cell In[2], line 21, in CoCo._compute_score(self, k, n, K, N)
#      19     return 0
#      20 sign = (k / n) - (K / N)
# ---> 21 p = hypergeom.pmf(k, N, K, n)
#      22 return 0 if p == 0 else abs(math.log10(p)) * (-1 if sign < 0 else 1)
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:3392, in rv_discrete.pmf(self, k, *args, **kwds)
#    3390 if np.any(cond):
#    3391     goodargs = argsreduce(cond, *((k,)+args))
# -> 3392     place(output, cond, np.clip(self._pmf(*goodargs), 0, 1))
#    3393 if output.ndim == 0:
#    3394     return output[()]
#
# File <__array_function__ internals>:180, in place(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:1953, in place(arr, mask, vals)
#    1949 if not isinstance(arr, np.ndarray):
#    1950     raise TypeError("argument 1 must be numpy.ndarray, "
#    1951                     "not {name}".format(name=type(arr).__name__))
# -> 1953 return _insert(arr, mask, vals)
#
# KeyboardInterrupt:

# %%
# pathInt is a function connected to PAGER api to retrieve the m-type relationships of PAGs using a list of PAG IDs
# example:
PAGint = PAGER.pathInt(list(PAG_result.GS_ID))
PAGint.GS_A_ID
pag_graph = WeightedGraph()
for node1, node2, weight in zip(PAGint.GS_A_ID, PAGint.GS_B_ID,PAGint.SIMILARITY):
  pag_graph.add_edge(node1, node2, weight)

pag_graph
BEST_SUB, MAX_COCO = find_max_coco_subgraph(pag_graph)
BEST_SUB
MAX_COCO
# Out:
# 0    WAG000628
# 1    WAG000644
# 2    WAG000628
# 3    WAG000212
# Name: GS_A_ID, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/qi/Workspace/super_pag/SUPER_PAG_SOLVER.ipynb Cell 7 line 1
#       <a href='vscode-notebook-cell:/Users/qi/Workspace/super_pag/SUPER_PAG_SOLVER.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a>   pag_graph.add_edge(node1, node2, weight)
#       <a href='vscode-notebook-cell:/Users/qi/Workspace/super_pag/SUPER_PAG_SOLVER.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a> pag_graph
# ---> <a href='vscode-notebook-cell:/Users/qi/Workspace/super_pag/SUPER_PAG_SOLVER.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a> BEST_SUB, MAX_COCO = find_max_coco_subgraph(pag_graph, 10)
#      <a href='vscode-notebook-cell:/Users/qi/Workspace/super_pag/SUPER_PAG_SOLVER.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a> BEST_SUB
#      <a href='vscode-notebook-cell:/Users/qi/Workspace/super_pag/SUPER_PAG_SOLVER.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a> MAX_COCO
#
# TypeError: find_max_coco_subgraph() takes 1 positional argument but 2 were given
